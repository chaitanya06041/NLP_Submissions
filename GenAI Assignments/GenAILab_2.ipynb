# %%
from transformers import pipeline
# Out:
# WARNING:tensorflow:From C:\Users\chait\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
qa_pipeline = pipeline("text-generation", model="gpt2")

#Interview Approach
def interview_approach(question):
    return qa_pipeline(question)[0]['generated_text']

#Chain of Thought
def cot_prompting(question):
    prompt = f"Q: {question}\nLet's break it down step by step to find the answer."
    return qa_pipeline(prompt)[0]['generated_text']

#Tree of Thought
def tot_prompting(question):
    prompt = f"Q: {question}\nLet's consider multiple possible solutions and evaluate the best one."
    return qa_pipeline(prompt)[0]['generated_text']

#Zero-Shot vs. Few-Shot Prompting
def zero_shot(question):
    return qa_pipeline(question)[0]['generated_text']

def few_shot(question):
    examples = "Q: What is 12 + 15? A: 27\nQ: What is 8 * 3? A: 24\n"
    return qa_pipeline(examples + f"Q: {question}\nA:")[0]['generated_text']
# Out:
# Device set to use cuda:0

# %%
test_question = "What is 25 + 37?"

# Running all approaches
print("Interview Approach:", interview_approach(test_question))
print("Chain of Thought:", cot_prompting(test_question))
print("Tree of Thought:", tot_prompting(test_question))
print("Zero-Shot:", zero_shot(test_question))
print("Few-Shot:", few_shot(test_question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# C:\Users\chait\AppData\Roaming\Python\Python311\site-packages\transformers\integrations\sdpa_attention.py:53: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Interview Approach: What is 25 + 37?
#
# What is 25 with 38?
#
# There are several ways to say I miss this answer and more are said when answering. I can still tell that I miss it by myself, but it is always good to
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chain of Thought: Q: What is 25 + 37?
# Let's break it down step by step to find the answer. First we need to find the correct answer.
# We start from our list below the top row with the correct answer. We'll come back
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Tree of Thought: Q: What is 25 + 37?
# Let's consider multiple possible solutions and evaluate the best one.
# Let us assume an all-or-nothing (or "no) solution. We can use a solution where only 36% of items are
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Zero-Shot: What is 25 + 37?
#
# It's very easy to read and you can even get off to a very fine start. In fact, that's all that mattered to get started with the game. In any case you'll want to make sure
# Few-Shot: Q: What is 12 + 15? A: 27
# Q: What is 8 * 3? A: 24
# Q: What is 25 + 37?
# A: 11
# Q: What is 12 + 17? A: 8
# Q
